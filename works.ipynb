# %%
import win32com.client as wincl
import speech_recognition as sr
import subprocess
import webbrowser
from pygame import mixer

speak=wincl.Dispatch('SAPI.SpVoice')
print('Welcome! I have been expecting you. This is a program that predicts the winning team of a football game in the Knockout League. The league includes four teams. FC Barcelona, Real Madrid, PSG and Juventus. Time to see how it works!')
speak.Speak('Welcome! I have been expecting you. This is a program that predicts the winning team of a football game in the Knockout League. The league includes four teams. FC Barcelona, Real Madrid, PSG and Juventus. Time to see how it works!')

r=sr.Recognizer()
with sr.Microphone() as source:
    r.adjust_for_ambient_noise(source)
    print('Please speak out name of the first team')
    speak.Speak('Please speak out name of the first team')
    audio=r.listen(source)
    
    try:
        team_1 = r.recognize_google(audio)
        print('Team 1: ',r.recognize_google(audio))
    except Exception as e:
        print(e)
    

    
r1=sr.Recognizer()
with sr.Microphone() as source1:
    r1.adjust_for_ambient_noise(source1)
    print('Please speak out name of the second team')
    speak.Speak('Please speak out name of the second team')
    audio=r1.listen(source1)

    try:
        team_2 = r1.recognize_google(audio)
        print('Team 2: ', r1.recognize_google(audio))
    except Exception as e1:
        print(e1)
    


r2=sr.Recognizer()
with sr.Microphone() as source2:
    r2.adjust_for_ambient_noise(source2)
    print('Is Team 1 the home team? Say YES or NO')
    speak.Speak('Is Team 1 the home team? Say YES or NO.')
    audio=r2.listen(source2)
    
    try:
        home = r2.recognize_google(audio)
        print('You: ',r2.recognize_google(audio))
    except Exception as e2:
        print(e2)

class team1:
    mp=12
    mw2=5
    mw3=4
    mw4=3
    mwa2wh=1
    mwa2ah=3
    mwa3wh=2
    mwa3ah=1
    mwa4wh=1
    mwa4ah=1
    ap1a2=43
    ap1a3=54
    ap1a4=51
    mwa2wpg=2
    mwa2wpl=1
    mpa2wpg=4
    mpa2wpl=1
    mwa3wpg=1
    mwa3wpl=2
    mpa3wpg=2
    mpa3wpl=2
    mwa4wpg=1
    mwa4wpl=1
    mpa4wpg=2
    mpa4wpl=1
    
class team2:
    mp=13
    mw1=5
    mw3=5
    mw4=3
    mwa1wh=3
    mwa1ah=1
    mwa3wh=2
    mwa3ah= 1
    mwa4wh=1
    mwa4ah=1
    ap2a1=43
    ap2a3=48
    ap2a4=54
    mwa1wpg=1
    mwa1wpl=2
    mpa1wpg=2
    mpa1wpl=3
    mwa3wpg=2
    mwa3wpl=1
    mpa3wpg=2
    mpa3wpl=3
    mwa4wpg=1
    mwa4wpl=1
    mpa4wpg=2
    mpa4wpl=1

class team3:
    mp=14
    mw1=5
    mw2=4
    mw4=5
    mwa1wh=2
    mwa1ah=2
    mwa2wh=2
    mwa2ah=1
    mwa4wh=3
    mwa4ah=1
    ap3a1=54
    ap3a2=52
    ap3a4=55
    mwa1wpg=3
    mwa1wpl=1
    mpa1wpg=3
    mpa1wpl=2
    mwa2wpg=2
    mwa2wpl=1
    mpa2wpg=2
    mpa2wpl=2
    mwa4wpg=2
    mwa4wpl=2
    mpa4wpg=3
    mpa4wpl=2
    
class team4:
    mp=10
    mw1=3
    mw2=3
    mw3=4
    mwa1wh=1
    mwa1ah=1
    mwa2wh=1
    mwa2ah=1
    mwa3wh=3
    mwa3ah=1
    ap4a1=43
    ap4a2=53
    ap4a3=45
    mwa1wpg=1
    mwa1wpl=1
    mpa1wpg=1
    mpa1wpl=2
    mwa2wpg=1
    mwa2wpl=1
    mpa2wpg=2
    mpa2wpl=1
    mwa3wpg=1
    mwa3wpl=1
    mpa3wpg=3
    mpa3wpl=1
   
    
    
t1=team1()
t2=team2()
t3=team3()
t4=team4()



if(team_1=='FC Barcelona' and team_2=='Real Madrid'):
    if(home=='yes'):
        prob1= ((t1.mwa2wh/(t1.mwa2wh+t1.mwa3wh+t1.mwa4wh))*((t1.mwa2wh+t1.mwa3wh+t1.mwa4wh)/t1.mp))/(t1.mw2/t1.mp)
    elif(home=='no'):
        prob1=((t1.mwa2ah/(t1.mwa2ah+t1.mwa3ah+t1.mwa4ah))*((t1.mwa2ah+t1.mwa3ah+t1.mwa4ah)/t1.mp))/(t1.mw2/t1.mp)
        
    if(t1.ap1a2>50):
        prob2=t1.mwa2wpg/t1.mpa2wpg
    else:
        prob2=t1.mwa2wpl/t1.mpa2wpl
  
    probt1=((prob1*100)+(prob2*100))/2
    probt2=100-probt1

    if(probt1>50):
        print('The winning probability of FC Barcelona is',probt1,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of FC Barcelona is')
        speak.Speak(probt1)
        speak.Speak('percent')
    elif(probt2>50):
        print('The winning probability of Real Madrid is',probt2,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of Real Madrid is')
        speak.Speak(probt2)
        speak.Speak('percent')
    
elif(team_1=='FC Barcelona' and team_2=='PSG'):
    if(home=='yes'):
        prob1= ((t1.mwa2wh/(t1.mwa2wh+t1.mwa3wh+t1.mwa4wh))*((t1.mwa2wh+t1.mwa3wh+t1.mwa4wh)/t1.mp))/(t1.mw3/t1.mp)
        
    elif(home=='no'):
        prob1=((t1.mwa2ah/(t1.mwa2ah+t1.mwa3ah+t1.mwa4ah))*((t1.mwa2ah+t1.mwa3ah+t1.mwa4ah)/t1.mp))/(t1.mw2/t1.mp)
        
    if(t1.ap1a3>50):
        prob2=t1.mwa2wpg/t1.mpa2wpg
    else:
        prob2=t1.mwa2wpl/t1.mpa2wpl
   
    probt1=((prob1*100)+(prob2*100))/2
    probt2=100-probt1
    
    if(probt1>50):
        print('The winning probability of FC Barcelona is',probt1,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of FC Barcelona is')
        speak.Speak(probt1)
        speak.Speak('percent')
    elif(probt2>50):
        print('The winning probability of PSG is',probt2,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of PSG is')
        speak.Speak(probt2)
        speak.Speak('percent')
    
    
elif(team_1=='FC Barcelona' and team_2=='Juventus'):
    if(home=='yes'):
        prob1= ((t1.mwa2wh/(t1.mwa2wh+t1.mwa3wh+t1.mwa4wh))*((t1.mwa2wh+t1.mwa3wh+t1.mwa4wh)/t1.mp))/(t1.mw2/t1.mp)
       
    elif(home=='no'):
        prob1=((t1.mwa1ah/(t1.mwa2ah+t1.mwa3ah+t1.mwa4ah))*((t1.mwa2ah+t1.mwa3ah+t1.mwa4ah)/t1.mp))/(t1.mw2/t1.mp)
        
    if(t1.ap1a4>50):
        prob2=t1.mwa2wpg/t1.mpa2wpg
    else:
        prob2=t1.mwa2wpl/t1.mpa2wpl
   
    probt1=((prob1*100)+(prob2*100))/2
    probt2=100-probt1
    
    if(probt1>50):
        print('The winning probability of FC Barcelona is',probt1,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of FC Barcelona is')
        speak.Speak(probt1)
        speak.Speak('percent')
    elif(probt2>50):
        print('The winning probability of Juventus is',probt2,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of Juventus is')
        speak.Speak(probt2)
        speak.Speak('percent')

elif(team_1=='Real Madrid'and team_2=='FC Barcelona'):
    if(home=='yes'):
        prob1= ((t2.mwa1wh/(t2.mwa1wh+t2.mwa3wh+t2.mwa4wh))*((t2.mwa1wh+t2.mwa3wh+t2.mwa4wh)/t2.mp))/(t2.mw1/t2.mp)
        
    elif(home=='no'):
        prob1=((t2.mwa1ah/(t2.mwa1ah+t2.mwa3ah+t2.mwa4ah))*((t2.mwa1ah+t2.mwa3ah+t2.mwa4ah)/t2.mp))/(t2.mw2/t2.mp)
       
    if(t2.ap2a1>50):
        prob2=t2.mwa1wpg/t2.mpa1wpg
    else:
        prob2=t2.mwa1wpl/t2.mpa1wpl
  
    probt1=((prob1*100)+(prob2*100))/2
    probt2=100-probt1
    
    if(probt1>50):
        print('The winning probability of Real Madrid is',probt1,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of Real Madrid is')
        speak.Speak(probt1)
        speak.Speak('percent')
    elif(probt2>50):
        print('The winning probability of FC Barcelona is',probt2,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of FC Barcelona is')
        speak.Speak(probt2)
        speak.Speak('percent')
    
elif(team_1=='Real Madrid' and team_2=='PSG'):
    if(home=='yes'):
        prob1= ((t2.mwa3wh/(t2.mwa1wh+t2.mwa3wh+t2.mwa4wh))*((t2.mwa1wh+t2.mwa3wh+t2.mwa4wh)/t2.mp))/(t2.mw3/t2.mp)
        
    elif(home=='no'):
        prob1=((t2.mwa3ah/(t2.mwa1ah+t2.mwa3ah+t1.mwa4ah))*((t2.mwa1ah+t2.mwa3ah+t2.mwa4ah)/t2.mp))/(t2.mw3/t2.mp)
        
    if(t2.ap2a3>50):
        prob2=t2.mwa3wpg/t2.mpa3wpg
    else:
        prob2=t2.mwa3wpl/t2.mpa3wpl
    
    probt1=((prob1*100)+(prob2*100))/2
    probt2=100-probt1
    
    if(probt1>50):
        print('The winning probability of Real Madrid is',probt1,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of Real Madrid is')
        speak.Speak(probt1)
        speak.Speak('percent')
    elif(probt2>50):
        print('The winning probability of PSG is',probt2,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of PSG is')
        speak.Speak(probt2)
        speak.Speak('percent')
    
elif(team_1=='Real Madrid'and team_2=='Juventus'):
    if(home=='yes'):
        prob1= ((t2.mwa4wh/(t2.mwa1wh+t2.mwa3wh+t2.mwa4wh))*((t2.mwa1wh+t2.mwa3wh+t2.mwa4wh)/t2.mp))/(t2.mw4/t2.mp)
        
    elif(home=='no'):
        prob1=((t2.mwa4ah/(t2.mwa1ah+t2.mwa3ah+t1.mwa4ah))*((t2.mwa1ah+t2.mwa3ah+t2.mwa4ah)/t2.mp))/(t2.mw4/t2.mp)
        
    if(t2.ap2a4>50):
        prob2=t2.mwa4wpg/t2.mpa4wpg
    else:
        prob2=t2.mwa4wpl/t2.mpa4wpl
   
    probt1=((prob1*100)+(prob2*100))/2
    probt2=100-probt1
    
    if(probt1>50):
        print('The winning probability of Real Madrid is',probt1)
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of Real Madrid is')
        speak.Speak(probt1)
        speak.Speak('percent')
    elif(probt2>50):
        print('The winning probability of Juventus is',probt2)
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of Juventus is')
        speak.Speak(probt2)
        speak.Speak('percent')
        
elif(team_1=='PSG' and team_2=='FC Barcelona'):
    if(home=='yes'):
        prob1= ((t3.mwa1wh/(t3.mwa1wh+t3.mwa2wh+t3.mwa4wh))*((t3.mwa1wh+t3.mwa2wh+t3.mwa4wh)/t3.mp))/(t3.mw1/t3.mp)
       
    elif(home=='no'):
        prob1=((t3.mwa1ah/(t3.mwa1ah+t3.mwa3ah+t3.mwa4ah))*((t3.mwa1ah+t3.mwa2ah+t3.mwa4ah)/t3.mp))/(t3.mw1/t3.mp)
        
    if(t3.ap3a1>50):
        prob2=t3.mwa1wpg/t3.mpa1wpg
    else:
        prob2=t3.mwa1wpl/t3.mpa1wpl
    
    probt1=((prob1*100)+(prob2*100))/2
    probt2=100-probt1
    
    if(probt1>50):
        print('The winning probability of PSG is',probt1,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of PSG is')
        speak.Speak(round(probt1))
        speak.Speak('percent')
    elif(probt2>50):
        print('The winning probability of FC Barcelona is',probt2,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of FC Barcelona is')
        speak.Speak(round(probt2))
        speak.Speak('percent')
    
elif(team_1=='PSG' and team_2=='Real Madrid'):
    if(home=='yes'):
        prob1= ((t3.mwa2wh/(t3.mwa1wh+t3.mwa2wh+t3.mwa4wh))*((t3.mwa1wh+t3.mwa2wh+t3.mwa4wh)/t3.mp))/(t3.mw2/t3.mp)
        
    elif(home=='no'):
        prob1=((t3.mwa2ah/(t3.mwa1ah+t3.mwa3ah+t3.mwa4ah))*((t3.mwa1ah+t3.mwa2ah+t3.mwa4ah)/t3.mp))/(t3.mw2/t3.mp)
        
    if(t3.ap3a2>50):
        prob2=t3.mwa2wpg/t3.mpa2wpg
    else:
        prob2=t3.mwa2wpl/t3.mpa2wpl
   
    probt1=((prob1*100)+(prob2*100))/2
    probt2=100-probt1
    
    if(probt1>50):
        print('The winning probability of PSG is',probt1,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of PSG is')
        speak.Speak(round(probt1))
        speak.Speak('percent')
    elif(probt2>50):
        print('The winning probability of Real Madrid is',probt2,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of Real Madrid is')
        speak.Speak(round(probt2))
        speak.Speak('percent')
    
elif(team_1=='PSG' and team_2=='Juventus'):
    if(home=='yes'):
        prob1= ((t3.mwa4wh/(t3.mwa1wh+t3.mwa2wh+t3.mwa4wh))*((t3.mwa1wh+t3.mwa2wh+t3.mwa4wh)/t3.mp))/(t3.mw4/t3.mp)
        
    elif(home=='no'):
        prob1=((t3.mwa4ah/(t3.mwa1ah+t3.mwa4ah+t3.mwa4ah))*((t3.mwa1ah+t3.mwa2ah+t3.mwa4ah)/t3.mp))/(t3.mw4/t3.mp)
        
    if(t3.ap3a4>50):
        prob2=t3.mwa4wpg/t3.mpa4wpg
    else:
        prob2=t3.mwa4wpl/t3.mpa4wpl
    probt1=((prob1*100)+(prob2*100))/2
    probt2=100-probt1
    
    if(probt1>50):
        print('The winning probability of PSG is',probt1,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of PSG is')
        speak.Speak(round(probt1))
        speak.Speak('percent')
    elif(probt2>50):
        print('The winning probability of Juventus is',probt2,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of Juventus is')
        speak.Speak(round(probt2))
        speak.Speak('percent')
    
elif(team_1=='Juventus'and team_2=='FC Barcelona'):
    
    if(home=='yes'):
        prob1= ((t4.mwa1wh/(t4.mwa1wh+t4.mwa2wh+t4.mwa3wh))*((t4.mwa1wh+t4.mwa2wh+t4.mwa3wh)/t4.mp))/(t4.mw1/t4.mp)
        
    elif(home=='no'):
        prob1=((t4.mwa1ah/(t4.mwa1ah+t4.mwa3ah+t4.mwa2ah))*((t4.mwa1ah+t4.mwa2ah+t4.mwa3ah)/t4.mp))/(t4.mw1/t4.mp)
        
    if(t4.ap4a1>50):
        prob2=t4.mwa1wpg/t4.mpa1wpg
    else:
        prob2=t4.mwa1wpl/t4.mpa1wpl
   
    probt1=((prob1*100)+(prob2*100))/2
    probt2=100-probt1
   
    if(probt1>50):
        print('The winning probability of Juventus is',probt1,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of Juventus is')
        speak.Speak(round(probt1))
        speak.Speak('percent')
    elif(probt2>50):
        print('The winning probability of FC Barcelona is',probt2,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of FC Barcelona is')
        speak.Speak(round(probt2))
        speak.Speak('percent')
    
elif(team_1=='Juventus' and team_2=='Real Madrid'):
    if(home=='yes'):
        prob1= ((t4.mwa2wh/(t4.mwa1wh+t4.mwa2wh+t4.mwa3wh))*((t4.mwa1wh+t4.mwa2wh+t4.mwa3wh)/t4.mp))/(t4.mw2/t4.mp)
        
    elif(home=='no'):
        prob1=((t4.mwa2ah/(t4.mwa1ah+t4.mwa3ah+t4.mwa2ah))*((t4.mwa1ah+t4.mwa2ah+t4.mwa3ah)/t4.mp))/(t4.mw2/t4.mp)
        
    if(t4.ap4a2>50):
        prob2=t4.mwa2wpg/t4.mpa2wpg
    else:
        prob2=t4.mwa2wpl/t4.mpa2wpl
   
    probt1=((prob1*100)+(prob2*100))/2
    probt2=100-probt1
    
    if(probt1>50):
        print('The winning probability of Juventus is',probt1,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of Juventus is')
        speak.Speak(round(probt1))
        speak.Speak('percent')
    elif(probt2>50):
        print('The winning probability of Real Madrid is',probt2,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of Real Madrid is')
        speak.Speak(round(probt2))
        speak.Speak('percent')
        
elif(team_1=='Juventus'and team_2=='PSG'):
    if(home=='yes'):
        prob1= ((t4.mwa3wh/(t4.mwa1wh+t4.mwa3wh+t4.mwa2wh))*((t4.mwa1wh+t4.mwa3wh+t4.mwa2wh)/t4.mp))/(t4.mw3/t4.mp)
        
    elif(home=='no'):
        prob1=((t4.mwa3ah/(t4.mwa1ah+t4.mwa3ah+t4.mwa2ah))*((t4.mwa1ah+t4.mwa3ah+t4.mwa2ah)/t4.mp))/(t4.mw3/t4.mp)
       
    if(t4.ap4a3>50):
        prob2=t4.mwa3wpg/t4.mpa3wpg
    else:
        prob2=t4.mwa3wpl/t4.mpa3wpl
   
    probt1=((prob1*100)+(prob2*100))/2
    probt2=100-probt1
    
    if(probt1>50):
        print('The winning probability of Juventus is',probt1,'%')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of Juventus is')
        speak.Speak(round(probt1))
        speak.Speak('percent')
    elif(probt2>50):
        print('The winning probability of PSG is',probt2,'%\n\n')
        speak=wincl.Dispatch('SAPI.SpVoice')
        speak.Speak('The winning probability of PSG is')
        speak.Speak(round(probt2))
        speak.Speak('percent')
        
#secondphase
        
r3=sr.Recognizer()
with sr.Microphone() as source:
    r3.adjust_for_ambient_noise(source)
    speak=wincl.Dispatch('SAPI.SpVoice')
    print('Do you have anything further to ask?')
    speak.Speak('Do you have anything further to ask?')
    audio=r3.listen(source)

try:
    print('You: ',r3.recognize_google(audio))
except Exception as e:
    print(e)
    
    
if(r3.recognize_google(audio)=='yes'):
    print('Please Command')
    r4=sr.Recognizer()
    speak=wincl.Dispatch('SAPI.SpVoice')
    speak.Speak('Please Command')
    with sr.Microphone() as source:
        audio=r4.listen(source)
        try:
            print('You: ', r4.recognize_google(audio))
        except Exception as e:
            print(e)
        
    if('updates' in r4.recognize_google(audio)):
                    speak=wincl.Dispatch('SAPI.SpVoice')
                    print("Reply: Let's go")
                    speak.Speak("Let's go!")
                    webbrowser.open_new_tab('https://www.goal.com/en-in/live-scores')
    if('song' in r4.recognize_google(audio)):
        speak=wincl.Dispatch('SAPI.SpVoice')
        print("Reply: Okay")
        speak.Speak("Okay")
        with sr.Microphone() as source:
            audio=r4.listen(source)
        try:
            print('You: ', r4.recognize_google(audio))
        except Exception as e:
            print(e)
        if('Cheer me up' or 'Play me a song' or 'song' in r4.recognize_google(audio)):
            mixer.init()
            mixer.music.load('C:\\Users\\warke\\Music\\Live it up.mp3')
            mixer.music.play()
        
else:
    print('Okay, Bye bye!')
    speak.Speak('Okay, Bye bye!')
# Out:
# Welcome! I have been expecting you. This is a program that predicts the winning team of a football game in the Knockout League. The league includes four teams. FC Barcelona, Real Madrid, PSG and Juventus. Time to see how it works!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\speech_recognition\__init__.py in get_pyaudio()
#     107         try:
# --> 108             import pyaudio
#     109         except ImportError:
#
# ModuleNotFoundError: No module named 'pyaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-60164e5d82dc> in <module>()
#      10
#      11 r=sr.Recognizer()
# ---> 12 with sr.Microphone() as source:
#      13     r.adjust_for_ambient_noise(source)
# ...
